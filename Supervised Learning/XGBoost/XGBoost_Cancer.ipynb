# %%
# Loading Libraries

import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt 
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

from sklearn.model_selection import GridSearchCV

# %%
data = pd.read_csv("breast_cancer_data.csv")
data.drop(['id','Unnamed: 32'],axis=1,inplace=True)
# map function for mapping benign into 0 and malignant into 1
data['diagnosis'] = data['diagnosis'].map({'B':0,'M':1})

X=data.drop(['diagnosis'],axis=1)
y=data['diagnosis']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,random_state=42)

# %%
! pip install xgboost

# %%
from xgboost import XGBClassifier

# %%
params = [{'learning_rate':[0.05,0.10,0.15,0.20,0.25,0.30],
'max_depth':[3,4,5,6,8,15],
'min_child_weight':[1,3,5,7],
'gamma':[0.0,0.1,0.2,0.3,0.4],
'colsample_bytree':[0.3,0.4,0.5]}]

# %%
# Learning rate is the Lamda or error given in final equation which is Zigma*(0+Lamda*SW)
# Gamma is the Lamda given in Similarity weight equatiion where in denominator we add an error lamba.
# Min child weight is for when making a tree, we look for SW of a leaf node and when the SW of the leaf node is below the particular given min child weight, then further split of the leaf node will not takes place.
# Max depth is given for making trees of depth upto which the given number.
# Colsample bytree is used to given the number of columns to take randomly for making a tree in a random forest.

# %%
xgb_clf = XGBClassifier()

grid_clf = GridSearchCV(xgb_clf,params,cv=10,scoring='accuracy')

# %%
grid_clf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=XGBClassifier(),
#              param_grid=[{'colsample_bytree': [0.3, 0.4, 0.5],
#                           'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                           'learning_rate': [0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
#                           'max_depth': [3, 4, 5, 6, 8, 15],
#                           'min_child_weight': [1, 3, 5, 7]}],
#              scoring='accuracy')

# %%
grid_clf.best_score_
# Out:
# 0.9815789473684211

# %%
grid_clf.best_params_
# Out:
# {'colsample_bytree': 0.5,
#  'gamma': 0.4,
#  'learning_rate': 0.25,
#  'max_depth': 5,
#  'min_child_weight': 1}
